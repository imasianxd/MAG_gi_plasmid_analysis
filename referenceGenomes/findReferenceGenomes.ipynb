# %%
import pandas as pd
import matplotlib as mp
import numpy as np
import os
pd.options.display.max_colwidth = 999

# %%
chrDir = "./tsv/chromosome/"
plasDir = "./tsv/plasmid/"

chromosomes = {}
plas = {}

for file in os.listdir(chrDir):
    index = file.split('.')[1]
    try:
        chromosomes[index] = pd.read_csv(chrDir + file, sep='\t', comment='#', header=None)
        chromosomes[index].columns = ["identity", "shared-hashes", "median-multiplicity", "p-value", "query-ID", "query-comment"]
    except:
        chromosomes[index] = "NA" 
for file in os.listdir(plasDir):
    index = file.split('.')[1]
    try:
        plas[index] = pd.read_csv(plasDir + file, sep='\t', comment='#', header=None)
        plas[index].columns = ["identity", "shared-hashes", "median-multiplicity", "p-value", "query-ID", "query-comment"]
    except:
        plas[index] = pd.DataFrame()

taxa = pd.read_csv("taxa_metadata.tsv", sep='\t', comment='#', header=None)
taxa.columns = ["spp","bioid","accesion","type"]
taxaMap = {}
for index,row in taxa.iterrows():
    key = taxa.loc[index,"accesion"]
    value = row
    taxaMap[key]=value
print (taxaMap)
# Out:
# {'NC_009338': spp         Mycobacterium gilvum
# bioid               SAMN02598346
# accesion               NC_009338
# type                  chromosome
# Name: 0, dtype: object, 'NC_009339': spp         Mycobacterium gilvum
# bioid               SAMN02598346
# accesion               NC_009339
# type                     plasmid
# Name: 1, dtype: object, 'NC_009340': spp         Mycobacterium gilvum
# bioid               SAMN02598346
# accesion               NC_009340
# type                     plasmid
# Name: 2, dtype: object, 'NC_009341': spp         Mycobacterium gilvum
# bioid               SAMN02598346
# accesion               NC_009341
# type                     plasmid
# Name: 3, dtype: object, 'NC_007606': spp         Shigella dysenteriae
# bioid               SAMN02603600
# accesion               NC_007606
# type                  chromosome
# Name: 4, dtype: object, 'NC_009344': spp         Shigella dysenteriae
# bioid               SAMN02603600
# accesion               NC_009344
# type                     plasmid
# Name: 5, dtype: object, 'NC_007607': spp         Shigella dysenteriae
# bioid               SAMN02603600
# accesion               NC_007607
# type                     plasmid
# Name: 6, dtype: object, 'NC_004337': spp         Shigella flexneri
# bioid            SAMN02603599
# accesion            NC_004337
# type               chromosome
# Name: 7, dtype: object, 'NC_004851': spp         Shigella flexneri
# bioid            SAMN02603599
# accesion            NC_004851
# type                  plasmid
# Name: 8, dtype: object, 'NZ_CP007772': spp         Campylobacter subantarcticus
# bioid                       SAMN03248548
# accesion                     NZ_CP007772
# type                          chromosome
# Name: 9, dtype: object, 'NC_004578': spp         Pseudomonas syringae group genomosp. 3
# bioid                                 SAMN02604017
# accesion                                 NC_004578
# type                                    chromosome
# Name: 10, dtype: object, 'NC_004633': spp         Pseudomonas syringae group genomosp. 3
# bioid                                 SAMN02604017
# accesion                                 NC_004633
# type                                       plasmid
# Name: 11, dtype: object, 'NC_004632': spp         Pseudomonas syringae group genomosp. 3
# bioid                                 SAMN02604017
# accesion                                 NC_004632
# type                                       plasmid
# Name: 12, dtype: object, 'NC_010170': spp         Bordetella petrii
# bioid            SAMEA3138272
# accesion            NC_010170
# type               chromosome
# Name: 13, dtype: object, 'NC_016749': spp         Streptococcus macedonicus
# bioid                    SAMEA2272145
# accesion                    NC_016749
# type                       chromosome
# Name: 14, dtype: object, 'NC_016750': spp         Streptococcus macedonicus
# bioid                    SAMEA2272145
# accesion                    NC_016750
# type                          plasmid
# Name: 15, dtype: object, 'NC_010610': spp         Lactobacillus fermentum
# bioid                  SAMD00060917
# accesion                  NC_010610
# type                     chromosome
# Name: 16, dtype: object, 'NC_022236': spp         Streptococcus constellatus
# bioid                     SAMN02603657
# accesion                     NC_022236
# type                        chromosome
# Name: 17, dtype: object, 'NZ_CP022374': spp         Acetobacter pasteurianus
# bioid                   SAMN06855882
# accesion                 NZ_CP022374
# type                      chromosome
# Name: 18, dtype: object, 'NZ_CP016483': spp         Synechococcus sp. PCC 8807
# bioid                     SAMN04422305
# accesion                   NZ_CP016483
# type                        chromosome
# Name: 19, dtype: object, 'NZ_CP016484': spp         Synechococcus sp. PCC 8807
# bioid                     SAMN04422305
# accesion                   NZ_CP016484
# type                           plasmid
# Name: 20, dtype: object, 'NZ_CP016485': spp         Synechococcus sp. PCC 8807
# bioid                     SAMN04422305
# accesion                   NZ_CP016485
# type                           plasmid
# Name: 21, dtype: object, 'NZ_CP016486': spp         Synechococcus sp. PCC 8807
# bioid                     SAMN04422305
# accesion                   NZ_CP016486
# type                           plasmid
# Name: 22, dtype: object, 'NZ_CP016487': spp         Synechococcus sp. PCC 8807
# bioid                     SAMN04422305
# accesion                   NZ_CP016487
# type                           plasmid
# Name: 23, dtype: object, 'NZ_CP016488': spp         Synechococcus sp. PCC 8807
# bioid                     SAMN04422305
# accesion                   NZ_CP016488
# type                           plasmid
# Name: 24, dtype: object, 'NZ_CP016489': spp         Synechococcus sp. PCC 8807
# bioid                     SAMN04422305
# accesion                   NZ_CP016489
# type                           plasmid
# Name: 25, dtype: object, 'NC_017445': spp         Erwinia sp. Ejp617
# bioid             SAMN02603467
# accesion             NC_017445
# type                chromosome
# Name: 26, dtype: object, 'NC_017442': spp         Erwinia sp. Ejp617
# bioid             SAMN02603467
# accesion             NC_017442
# type                   plasmid
# Name: 27, dtype: object, 'NC_017446': spp         Erwinia sp. Ejp617
# bioid             SAMN02603467
# accesion             NC_017446
# type                   plasmid
# Name: 28, dtype: object, 'NC_017443': spp         Erwinia sp. Ejp617
# bioid             SAMN02603467
# accesion             NC_017443
# type                   plasmid
# Name: 29, dtype: object, 'NC_017447': spp         Erwinia sp. Ejp617
# bioid             SAMN02603467
# accesion             NC_017447
# type                   plasmid
# Name: 30, dtype: object, 'NC_017444': spp         Erwinia sp. Ejp617
# bioid             SAMN02603467
# accesion             NC_017444
# type                   plasmid
# Name: 31, dtype: object, 'NC_005957': spp         Bacillus thuringiensis
# bioid                 SAMN02598265
# accesion                 NC_005957
# type                    chromosome
# Name: 32, dtype: object, 'NC_006578': spp         Bacillus thuringiensis
# bioid                 SAMN02598265
# accesion                 NC_006578
# type                       plasmid
# Name: 33, dtype: object, 'NZ_CP016896': spp         Acinetobacter soli
# bioid             SAMN05554081
# accesion           NZ_CP016896
# type                chromosome
# Name: 34, dtype: object, 'NZ_CP016897': spp         Acinetobacter soli
# bioid             SAMN05554081
# accesion           NZ_CP016897
# type                   plasmid
# Name: 35, dtype: object, 'NZ_CP016898': spp         Acinetobacter soli
# bioid             SAMN05554081
# accesion           NZ_CP016898
# type                   plasmid
# Name: 36, dtype: object, 'NZ_CP016899': spp         Acinetobacter soli
# bioid             SAMN05554081
# accesion           NZ_CP016899
# type                   plasmid
# Name: 37, dtype: object, 'NZ_CP016900': spp         Acinetobacter soli
# bioid             SAMN05554081
# accesion           NZ_CP016900
# type                   plasmid
# Name: 38, dtype: object, 'NZ_CP016901': spp         Acinetobacter soli
# bioid             SAMN05554081
# accesion           NZ_CP016901
# type                   plasmid
# Name: 39, dtype: object, 'NZ_CP016902': spp         Acinetobacter soli
# bioid             SAMN05554081
# accesion           NZ_CP016902
# type                   plasmid
# Name: 40, dtype: object, 'NZ_CP016903': spp         Acinetobacter soli
# bioid             SAMN05554081
# accesion           NZ_CP016903
# type                   plasmid
# Name: 41, dtype: object, 'NZ_CP014912': spp         Lactobacillus paracollinoides
# bioid                        SAMN04505735
# accesion                      NZ_CP014912
# type                           chromosome
# Name: 42, dtype: object, 'NZ_CP014913': spp         Lactobacillus paracollinoides
# bioid                        SAMN04505735
# accesion                      NZ_CP014913
# type                              plasmid
# Name: 43, dtype: object, 'NZ_CP014914': spp         Lactobacillus paracollinoides
# bioid                        SAMN04505735
# accesion                      NZ_CP014914
# type                              plasmid
# Name: 44, dtype: object, 'NZ_CP014234': spp         Moraxella osloensis
# bioid              SAMN04435858
# accesion            NZ_CP014234
# type                 chromosome
# Name: 45, dtype: object, 'NZ_CP014238': spp         Moraxella osloensis
# bioid              SAMN04435858
# accesion            NZ_CP014238
# type                    plasmid
# Name: 46, dtype: object, 'NZ_CP014237': spp         Moraxella osloensis
# bioid              SAMN04435858
# accesion            NZ_CP014237
# type                    plasmid
# Name: 47, dtype: object, 'NZ_CP014236': spp         Moraxella osloensis
# bioid              SAMN04435858
# accesion            NZ_CP014236
# type                    plasmid
# Name: 48, dtype: object, 'NZ_CP014235': spp         Moraxella osloensis
# bioid              SAMN04435858
# accesion            NZ_CP014235
# type                    plasmid
# Name: 49, dtype: object, 'NZ_CP014623': spp         Lactobacillus backii
# bioid               SAMN04505726
# accesion             NZ_CP014623
# type                  chromosome
# Name: 50, dtype: object, 'NZ_CP014624': spp         Lactobacillus backii
# bioid               SAMN04505726
# accesion             NZ_CP014624
# type                     plasmid
# Name: 51, dtype: object, 'NZ_CP014625': spp         Lactobacillus backii
# bioid               SAMN04505726
# accesion             NZ_CP014625
# type                     plasmid
# Name: 52, dtype: object, 'NZ_CP014626': spp         Lactobacillus backii
# bioid               SAMN04505726
# accesion             NZ_CP014626
# type                     plasmid
# Name: 53, dtype: object, 'NZ_CP014627': spp         Lactobacillus backii
# bioid               SAMN04505726
# accesion             NZ_CP014627
# type                     plasmid
# Name: 54, dtype: object, 'NZ_CP014628': spp         Lactobacillus backii
# bioid               SAMN04505726
# accesion             NZ_CP014628
# type                     plasmid
# Name: 55, dtype: object, 'NZ_CP014629': spp         Lactobacillus backii
# bioid               SAMN04505726
# accesion             NZ_CP014629
# type                     plasmid
# Name: 56, dtype: object, 'NZ_CP014630': spp         Lactobacillus backii
# bioid               SAMN04505726
# accesion             NZ_CP014630
# type                     plasmid
# Name: 57, dtype: object, 'NZ_CP014631': spp         Lactobacillus backii
# bioid               SAMN04505726
# accesion             NZ_CP014631
# type                     plasmid
# Name: 58, dtype: object, 'NZ_CP014632': spp         Lactobacillus backii
# bioid               SAMN04505726
# accesion             NZ_CP014632
# type                     plasmid
# Name: 59, dtype: object, 'NZ_CP014633': spp         Lactobacillus backii
# bioid               SAMN04505726
# accesion             NZ_CP014633
# type                     plasmid
# Name: 60, dtype: object, 'NZ_CP008788': spp         Klebsiella oxytoca
# bioid             SAMN02786843
# accesion           NZ_CP008788
# type                chromosome
# Name: 61, dtype: object, 'NZ_CP008789': spp         Klebsiella oxytoca
# bioid             SAMN02786843
# accesion           NZ_CP008789
# type                   plasmid
# Name: 62, dtype: object, 'NZ_CP008790': spp         Klebsiella oxytoca
# bioid             SAMN02786843
# accesion           NZ_CP008790
# type                   plasmid
# Name: 63, dtype: object, 'NZ_CP008791': spp         Klebsiella oxytoca
# bioid             SAMN02786843
# accesion           NZ_CP008791
# type                   plasmid
# Name: 64, dtype: object, 'NC_011894': spp         Methylobacterium nodulans
# bioid                    SAMN00000043
# accesion                    NC_011894
# type                       chromosome
# Name: 65, dtype: object, 'NC_011892': spp         Methylobacterium nodulans
# bioid                    SAMN00000043
# accesion                    NC_011892
# type                          plasmid
# Name: 66, dtype: object, 'NC_011887': spp         Methylobacterium nodulans
# bioid                    SAMN00000043
# accesion                    NC_011887
# type                          plasmid
# Name: 67, dtype: object, 'NC_011893': spp         Methylobacterium nodulans
# bioid                    SAMN00000043
# accesion                    NC_011893
# type                          plasmid
# Name: 68, dtype: object, 'NC_011895': spp         Methylobacterium nodulans
# bioid                    SAMN00000043
# accesion                    NC_011895
# type                          plasmid
# Name: 69, dtype: object, 'NC_011888': spp         Methylobacterium nodulans
# bioid                    SAMN00000043
# accesion                    NC_011888
# type                          plasmid
# Name: 70, dtype: object, 'NC_011889': spp         Methylobacterium nodulans
# bioid                    SAMN00000043
# accesion                    NC_011889
# type                          plasmid
# Name: 71, dtype: object, 'NC_011890': spp         Methylobacterium nodulans
# bioid                    SAMN00000043
# accesion                    NC_011890
# type                          plasmid
# Name: 72, dtype: object, 'NZ_CP015093': spp         Pelagibaca abyssi
# bioid            SAMN04562614
# accesion          NZ_CP015093
# type               chromosome
# Name: 73, dtype: object, 'NZ_CP015091': spp         Pelagibaca abyssi
# bioid            SAMN04562614
# accesion          NZ_CP015091
# type                  plasmid
# Name: 74, dtype: object, 'NZ_CP015090': spp         Pelagibaca abyssi
# bioid            SAMN04562614
# accesion          NZ_CP015090
# type                  plasmid
# Name: 75, dtype: object, 'NZ_CP015092': spp         Pelagibaca abyssi
# bioid            SAMN04562614
# accesion          NZ_CP015092
# type                  plasmid
# Name: 76, dtype: object, 'NZ_CP015095': spp         Pelagibaca abyssi
# bioid            SAMN04562614
# accesion          NZ_CP015095
# type                  plasmid
# Name: 77, dtype: object, 'NZ_CP015089': spp         Pelagibaca abyssi
# bioid            SAMN04562614
# accesion          NZ_CP015089
# type                  plasmid
# Name: 78, dtype: object, 'NZ_CP015094': spp         Pelagibaca abyssi
# bioid            SAMN04562614
# accesion          NZ_CP015094
# type                  plasmid
# Name: 79, dtype: object, 'NZ_CP015097': spp         Pelagibaca abyssi
# bioid            SAMN04562614
# accesion          NZ_CP015097
# type                  plasmid
# Name: 80, dtype: object, 'NZ_CP015096': spp         Pelagibaca abyssi
# bioid            SAMN04562614
# accesion          NZ_CP015096
# type                  plasmid
# Name: 81, dtype: object, 'NZ_CP013023': spp         Paenibacillus bovis
# bioid              SAMN04193493
# accesion            NZ_CP013023
# type                 chromosome
# Name: 82, dtype: object, 'NZ_CP021170': spp         Paenibacillus bovis
# bioid              SAMN04193493
# accesion            NZ_CP021170
# type                    plasmid
# Name: 83, dtype: object, 'NC_014100': spp         Caulobacter segnis
# bioid             SAMN02598513
# accesion             NC_014100
# type                chromosome
# Name: 84, dtype: object, 'NZ_CP017141': spp         Pedobacter steynii
# bioid             SAMN05582931
# accesion           NZ_CP017141
# type                chromosome
# Name: 85, dtype: object, 'NZ_LT635457': spp         Actinomyces sp. Marseille-P2985
# bioid                          SAMEA4555081
# accesion                        NZ_LT635457
# type                             chromosome
# Name: 86, dtype: object, 'NC_022584': spp         Streptococcus sp. I-G2
# bioid                 SAMN02299294
# accesion                 NC_022584
# type                    chromosome
# Name: 87, dtype: object, 'NZ_CP015866': spp         Streptomyces parvulus
# bioid                SAMN04924834
# accesion              NZ_CP015866
# type                   chromosome
# Name: 88, dtype: object, 'NZ_CP015867': spp         Streptomyces parvulus
# bioid                SAMN04924834
# accesion              NZ_CP015867
# type                      plasmid
# Name: 89, dtype: object, 'NC_005043': spp         Chlamydia pneumoniae
# bioid               SAMN02602979
# accesion               NC_005043
# type                  chromosome
# Name: 90, dtype: object, 'NC_006814': spp         Lactobacillus acidophilus
# bioid                    SAMN02603047
# accesion                    NC_006814
# type                       chromosome
# Name: 91, dtype: object, 'NZ_CP006905': spp         Clostridium baratii
# bioid              SAMN03222823
# accesion            NZ_CP006905
# type                 chromosome
# Name: 92, dtype: object, 'NZ_CP006906': spp         Clostridium baratii
# bioid              SAMN03222823
# accesion            NZ_CP006906
# type                    plasmid
# Name: 93, dtype: object, 'NC_010655': spp         Akkermansia muciniphila
# bioid                  SAMN00138213
# accesion                  NC_010655
# type                     chromosome
# Name: 94, dtype: object}

# %%
def getReferences(listOfMashHits, taxaMap):
    bestReference = []
    
    for key in listOfMashHits:
        bestHit = 0
        for index,rows in listOfMashHits[key].iterrows():
            curHash = int(listOfMashHits[key].loc[index, "shared-hashes"].split('/')[0])
            accession = listOfMashHits[key].loc[index,"query-comment"].split(' ')[0].split('.')[0]
            accType = taxaMap[accession].loc["type"]
            spp = taxaMap[accession].loc["spp"]
            grade = ""
            if (curHash >= bestHit and curHash > 10):
                bestHit = curHash
                grade = "best"
            elif (curHash < bestHit and curHash >= (bestHit - 100) and curHash >= 10 or curHash > 500):
                grade = "secondary"        
            elif(curHash >= 10):
                grade = "low"        
            else:
                grade = "noise"         
            bestReference.append(str(key)+ "\t" + grade+ "\t" + accession + "\t" + 
                                    accType + "\t" + spp + "\t" + str(curHash) + "\t" + 
                                    str(listOfMashHits[key].loc[index,"identity"]))
    return bestReference

bestChrReference = getReferences(chromosomes, taxaMap)
bestPlasReference = getReferences(plas, taxaMap)

# %%
with open("chrRef.tsv", 'w') as f:
    for item in bestChrReference:
        f.write("%s\n" % item)

with open("plasRef.tsv", 'w') as f:
    for item in bestPlasReference:
        f.write("%s\n" % item)
